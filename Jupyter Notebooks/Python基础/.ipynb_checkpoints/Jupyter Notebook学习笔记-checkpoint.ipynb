# %% [markdown]
# <a id='menu'></a>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Jupyter-Notebook-学习笔记" data-toc-modified-id="Jupyter-Notebook-学习笔记-1">Jupyter Notebook 学习笔记</a></span><ul class="toc-item"><li><span><a href="#1.-运行快捷键" data-toc-modified-id="1.-运行快捷键-1.1">1. 运行快捷键</a></span></li><li><span><a href="#2.-模式" data-toc-modified-id="2.-模式-1.2">2. 模式</a></span><ul class="toc-item"><li><span><a href="#2.1-编辑模式" data-toc-modified-id="2.1-编辑模式-1.2.1">2.1 编辑模式</a></span></li><li><span><a href="#2.2-命令模式" data-toc-modified-id="2.2-命令模式-1.2.2">2.2 命令模式</a></span></li></ul></li><li><span><a href="#3.-进阶功能" data-toc-modified-id="3.-进阶功能-1.3">3. 进阶功能</a></span><ul class="toc-item"><li><span><a href="#3.1-公式编辑：-LaTeX" data-toc-modified-id="3.1-公式编辑：-LaTeX-1.3.1">3.1 公式编辑： LaTeX</a></span></li><li><span><a href="#3.2-幻灯片制作" data-toc-modified-id="3.2-幻灯片制作-1.3.2">3.2 幻灯片制作</a></span></li><li><span><a href="#3.3-魔术关键字" data-toc-modified-id="3.3-魔术关键字-1.3.3">3.3 魔术关键字</a></span></li><li><span><a href="#3.4-导出功能" data-toc-modified-id="3.4-导出功能-1.3.4">3.4 导出功能</a></span></li><li><span><a href="#3.5-Matplotlib集成" data-toc-modified-id="3.5-Matplotlib集成-1.3.5">3.5 Matplotlib集成</a></span></li></ul></li><li><span><a href="#4.-代码交互" data-toc-modified-id="4.-代码交互-1.4">4. 代码交互</a></span><ul class="toc-item"><li><span><a href="#4.1-本地文件导入" data-toc-modified-id="4.1-本地文件导入-1.4.1">4.1 本地文件导入</a></span></li><li><span><a href="#4.2-运行python文件" data-toc-modified-id="4.2-运行python文件-1.4.2">4.2 运行python文件</a></span></li></ul></li><li><span><a href="#5.-Markdown" data-toc-modified-id="5.-Markdown-1.5">5. Markdown</a></span><ul class="toc-item"><li><span><a href="#5.1-斜体和粗体" data-toc-modified-id="5.1-斜体和粗体-1.5.1">5.1 斜体和粗体</a></span></li><li><span><a href="#5.2-分级标题" data-toc-modified-id="5.2-分级标题-1.5.2">5.2 分级标题</a></span></li><li><span><a href="#5.3-超链接" data-toc-modified-id="5.3-超链接-1.5.3">5.3 超链接</a></span><ul class="toc-item"><li><span><a href="#行内式" data-toc-modified-id="行内式-1.5.3.1"><em>行内式</em></a></span></li><li><span><a href="#参考式" data-toc-modified-id="参考式-1.5.3.2"><em>参考式</em></a></span></li><li><span><a href="#自动链接" data-toc-modified-id="自动链接-1.5.3.3"><em>自动链接</em></a></span></li></ul></li><li><span><a href="#5.4-锚点" data-toc-modified-id="5.4-锚点-1.5.4">5.4 锚点</a></span></li><li><span><a href="#5.5-列表" data-toc-modified-id="5.5-列表-1.5.5">5.5 列表</a></span><ul class="toc-item"><li><span><a href="#5.5.1-无序列表" data-toc-modified-id="5.5.1-无序列表-1.5.5.1">5.5.1 无序列表</a></span></li><li><span><a href="#5.5.2-有序列表" data-toc-modified-id="5.5.2-有序列表-1.5.5.2">5.5.2 有序列表</a></span></li><li><span><a href="#5.5.3-列表缩进" data-toc-modified-id="5.5.3-列表缩进-1.5.5.3">5.5.3 列表缩进</a></span></li><li><span><a href="#5.5.4-包含段落的列表" data-toc-modified-id="5.5.4-包含段落的列表-1.5.5.4">5.5.4 包含段落的列表</a></span></li><li><span><a href="#5.5.5-包含引用的列表" data-toc-modified-id="5.5.5-包含引用的列表-1.5.5.5">5.5.5 包含引用的列表</a></span></li><li><span><a href="#5.5.6-包含代码区块的引用" data-toc-modified-id="5.5.6-包含代码区块的引用-1.5.5.6">5.5.6 包含代码区块的引用</a></span></li><li><span><a href="#5.5.7-特殊情况" data-toc-modified-id="5.5.7-特殊情况-1.5.5.7">5.5.7 特殊情况</a></span></li></ul></li><li><span><a href="#5.6-引用" data-toc-modified-id="5.6-引用-1.5.6">5.6 引用</a></span><ul class="toc-item"><li><span><a href="#5.6.1-引用的多层嵌套" data-toc-modified-id="5.6.1-引用的多层嵌套-1.5.6.1">5.6.1 引用的多层嵌套</a></span></li><li><span><a href="#5.6.2-引用中的其他要素" data-toc-modified-id="5.6.2-引用中的其他要素-1.5.6.2">5.6.2 引用中的其他要素</a></span></li></ul></li><li><span><a href="#5.7-图像" data-toc-modified-id="5.7-图像-1.5.7">5.7 图像</a></span></li><li><span><a href="#5.8-注脚" data-toc-modified-id="5.8-注脚-1.5.8">5.8 注脚</a></span></li><li><span><a href="#5.9-LaTeX公式" data-toc-modified-id="5.9-LaTeX公式-1.5.9">5.9 LaTeX公式</a></span></li><li><span><a href="#5.10-流程图" data-toc-modified-id="5.10-流程图-1.5.10">5.10 流程图</a></span></li><li><span><a href="#5.11-表格" data-toc-modified-id="5.11-表格-1.5.11">5.11 表格</a></span></li><li><span><a href="#5.12-分割线" data-toc-modified-id="5.12-分割线-1.5.12">5.12 分割线</a></span></li><li><span><a href="#5.13-代码" data-toc-modified-id="5.13-代码-1.5.13">5.13 代码</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Jupyter Notebook 学习笔记

# %% [markdown]
# ## 1. 运行快捷键
#
# Shift+Enter  运行并换行
# Ctrl+Enter  运行不换行

# %% [markdown]
# ## 2. 模式
#
# ### 2.1 编辑模式
# * 编辑代码和文本
# * Enter键进入
# * 左侧绿色
# * 代码单元(Y)+Markdown单元(M)
#
# **快捷键：**
# >自动补全
# >
#     -Tab
# >全选
# >
#     -Ctrl+A
# >undo
# >
#     -Ctrl+Z
# >redo
# >
#     -Ctrl+Y
# >加注释（只有在代码模式）
# >
#     -Ctrl+/

# %% [markdown]
# ### 2.2 命令模式
# * 键盘输入命令
# * Esc键进入
# * 左侧蓝色
#
# **快捷键：**
#
# >进入代码单元
# >
#     -Y
# >进入Markdown单元
# >
#     -M
# >在上方添加一行
# >
#     -A
# >在下方添加一行
# >
#     -B
# >删除选定行
# >
#     -两次D
# >撤回删除行
# >
#     -Z
# >当前行加入line number
# >
#     -L
# >剪切行
# >
#     -X
# >复制行
# >
#     -C
# >在下方粘贴行
# >
#     -V
# >在上方粘贴行
# >
#     -Shift+V
# >保存
# >
#     -S
# >页面向上
# >
#     -Shift+Space
# >页面向下
# >
#     -Space
# >查看所有快捷键
# >
#     -H
# >选中多行
# >
#     -Shift+up/down
# >呼出命令面板
# >
#     -P
# >**另有移动、合并行功能**

# %% [markdown]
# <a id='LaTeX'></a>
# ## 3. 进阶功能
# ### 3.1 公式编辑： LaTeX

# %% [markdown]
# ### 3.2 幻灯片制作
# - View > Cell Toolbar > Slideshow
# - nbconvert来演示

# %% [markdown]
# ### 3.3 魔术关键字
# >- %：行魔法函数，只对本行代码生效。
#
# >- %%：Cell魔法函数，在整个Cell中生效，必须放于Cell首行。
#
# >- %lsmagic：列出所有的魔法函数
#
# >- %magic查看各个魔法函数的说明
#
# >- ?后面加上魔法函数名称，可以查看该函数的说明
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# ### 3.4 导出功能
# - HTML
# - Markdown
# - ReST
# - PDF（通过 LaTeX）
# - Raw Python

# %% [markdown]
# ### 3.5 Matplotlib集成
# 需要添加 %matplotlib inline

# %% [markdown]
# ## 4. 代码交互
# ### 4.1 本地文件导入
# 输入 %load xxxx.py # xxxx.py 为当前路径下的python文件

# %% [markdown]
# ### 4.2 运行python文件
# 输入 %run xxxxx.py

# %% [markdown]
# ## 5. Markdown
# ### 5.1 斜体和粗体
# >*斜体*：
# >
#     *斜体*
# >**粗体**：
# >
#     **粗体**
# >***粗斜***：
# >
#     ***粗斜***
# >~~删除线~~：
# >
#     ~~删除线~~(英文输入法)

# %% [markdown]
# ### 5.2 分级标题
# >n个`#`+空格+n级标题

# %% [markdown]
# ### 5.3 超链接
#
# #### *行内式*
#
# >[]里写链接文字，()里写链接地址, ()中的“ ”中可以为链接指定title属性，title属性可加可不加。title属性的效果是鼠标悬停在链接上会出现指定的 title文字。`[链接文字](链接地址 “链接标题”)`这样的形式。***链接地址与链接标题之间有一个空格***
#
# >**代码**
#
# >```markdown
# >    欢迎来到[梵居闹市](http://blog.leanote.com/freewalk)
#
# >    欢迎来到[梵居闹市](http://blog.leanote.com/freewalk "梵居闹市")
# ```
#
# >**效果**
#
# >欢迎来到[梵居闹市](http://blog.leanote.com/freewalk)
#
# >欢迎来到[梵居闹市](http://blog.leanote.com/freewalk "梵居闹市")
#
#
# #### *参考式*
#
# >参考式超链接一般用在学术论文上面，或者另一种情况，如果某一个链接在文章中多处使用，那么使用引用的方式创建链接将非常好，它可以让你对链接进行统一的管理。
#
# >参考式链接分为两部分，文中的写法`[链接文字][链接标记]`，在文本的任意位置添加`[链接标记]:链接地址 “链接标题”`，***链接地址与链接标题之间有一个空格***
#
# >如果链接文字本身可以做为链接标记，你也可以写成文中`[链接文字][]`，文外`[链接文字]：链接地址`的形式
#
# >**代码**
#
# >```markdown
# >    我经常去的几个网站[Google][1]、[Leanote][2]以及[自己的博客][3]
# >    [Leanote 笔记][2]是一个不错的[网站][]。
# >    [1]:http://www.google.com "Google"
# >    [2]:http://www.leanote.com "Leanote"
# >    [3]:http://http://blog.leanote.com/freewalk "梵居闹市"
# >    [网站]:http://http://blog.leanote.com/freewalk
# ```
#
# >**效果**
# >
# 我经常去的几个网站[Google][1]、[Leanote][2]以及[自己的博客][3]
# [Leanote 笔记][2]是一个不错的[网站][]。
# [1]:http://www.google.com "Google"
# [2]:http://www.leanote.com "Leanote"
# [3]:http://http://blog.leanote.com/freewalk "梵居闹市"
# [网站]:http://http://blog.leanote.com/freewalk
#
# #### *自动链接*
# >Markdown 支持以比较简短的自动链接形式来处理网址和电子邮件信箱，只要是用<>包起来， Markdown 就会自动把它转成链接。一般网址的链接文字就和链接地址一样
#
# >**代码**
#
# >```markdown
# ><http://example.com/>
#
# ><address@example.com>
# ```
#
# >**效果**
#
# ><http://example.com/>
#
# ><address@example.com>

# %% [markdown]
# ### 5.4 锚点
#
# >网页中，锚点其实就是页内超链接，也就是链接本文档内部的某些元素，实现当前页面中的跳转。比如我这里写下一个锚点，点击回到目录，就能跳转到目录。 在目录中点击这一节，就能跳过来。还有下一节的注脚。这些根本上都是用锚点来实现的。
#
# >要跳到的位置(the destination)
#
# >需要在要跳转到的位置添加下面语句:
# >
#     <a id=’the_destination'> </a>
#
# >这里的id取值任意赋值，下面在添加链接时要用
#
# >需要添加链接的文字，即点击该处可以跳转到the destination，在需要添加链接的文字后面加入：
#
# >
#     [需要添加链接的文字](#the_destination)
#
# >**效果**
#
# >回到[目录](#menu)

# %% [markdown]
# ### 5.5 列表

# %% [markdown]
# #### 5.5.1 无序列表
# 使用*， +， - 表示无序列表
# * 无序列表星号
# - 无序列表减号
# + 无序列表加号

# %% [markdown]
# #### 5.5.2 有序列表
# 使用数字加英文句点
# 1. 有序列表1
# 2. 有序列表2
# 3. 有序列表3

# %% [markdown]
# #### 5.5.3 列表缩进
# 列表项目标记通常是放在最左边，但是其实也可以缩进，最多 3 个空格，项目标记后面则一定要接着至少一个空格或制表符。
# **列表的下一行会自动缩进，要在上一行的结尾处打两个空格！**
#
# -   一行
# 二行

# %% [markdown]
# #### 5.5.4 包含段落的列表
# 一个列表包含多个段落：每个段落的首行都要缩进4个空格或者一个制表符（其余行可以顶格）
#
# -    一列表一段一行
# 一段二行
#
#     一列表二段一行
# 二段二行
#
#
# - 二列表一行

# %% [markdown]
# #### 5.5.5 包含引用的列表
# 如果要在列表项目内放进引用，那 > 就需要缩进：
# -  列表：
#   >引用1
#   >引用2

# %% [markdown]
# #### 5.5.6 包含代码区块的引用
# 如果要放代码区块的话，该区块就需要缩进两次，也就是 8 个空格或是 2 个制表符（中间要空一行）
# - 列表：
#
#         <我的代码>

# %% [markdown]
# #### 5.5.7 特殊情况
# 在特殊情况下，项目列表很可能会不小心产生，像是下面这样的写法：
#
#     1986. What a great season.
# 会显示成：
# 1986. What a great season.
#
# 换句话说，也就是在行首出现数字-句点-空白，要避免这样的状况，你可以在句点前面加上反斜杠：
#
#     1986\. What a great season.
# 会显示成：
# 1986\. What a great season.

# %% [markdown]
# ### 5.6 引用

# %% [markdown]
# 引用需要在被引用的文本前加上>符号。
# Markdown 也允许你偷懒只在整个段落的第一行最前面加上 >
# **代码**
# ```
# > 这是两段文字的引用，
# 占行1
# 占行2
#
# > 占行3
# 占行4
# ```
# **效果**
#
# > 这是两段文字的引用，
# 占行1
# 占行2
#
# > 占行3
# 占行4

# %% [markdown]
# #### 5.6.1 引用的多层嵌套
# >>>第一层引用
#
# >>第二层引用
#
# >第三层引用

# %% [markdown]
# #### 5.6.2 引用中的其他要素
# 引用的区块内也可以使用其他的 Markdown 语法，包括标题、列表、代码区块等
#
# **代码**
# ```
# > 1.   这是第一行列表项。
# > 2.   这是第二行列表项。
# >
# > 给出一些例子代码：
# >
# >     a+b=c
# ```
#
# **效果**
# > 1.   这是第一行列表项。
# > 2.   这是第二行列表项。
# >
# > 给出一些例子代码：
# >
# >     a+b=c
#
# ***特别注意***
# 引用中的代码区块如果有特殊的功能（直接打出就会执行功能，链接等），需要用以下形式放在引用中：
#     >```markdown
#     >    欢迎来到[梵居闹市](http://blog.leanote.com/freewalk)
#
#     >    欢迎来到[梵居闹市](http://blog.leanote.com/freewalk "梵居闹市")
#     ```
#
# 或者这样：
#     >需要在要跳转到的位置添加下面语句:
#     >
#         <a id=’the_destination'> </a>

# %% [markdown]
# ### 5.7 图像

# %% [markdown]
# ### 5.8 注脚

# %% [markdown]
# ### 5.9 LaTeX公式
# 更多见[3.1](#LaTeX)

# %% [markdown]
# ### 5.10 流程图

# %% [markdown]
# ### 5.11 表格

# %% [markdown]
# ### 5.12 分割线
# 你可以在一行中用三个以上的星号、减号、底线来建立一个分隔线，行内不能有其他东西。你也可以在星号或是减号中间插入空格。下面每种写法都可以建立分隔线：
# **代码**
# ```
# * * *
#
# ***
#
# *****
#
# - - -
#
# ---------------------------------------
# ```
# **效果**
# * * *
#
# ***
#
# *****
#
# - - -
#
# ---------------------------------------

# %% [markdown]
# ### 5.13 代码
# 插入程序代码的方式有两种，一种是利用缩进(Tab), 另一种是利用”`”符号（一般在ESC键下方）包裹代码
#
# 1. 插入行内代码，即插入一个单词或者一句代码的情况，使用``` `code` ```这样的形式插入。
# 2. 插入多行代码，可以使用缩进或者``` `code` ```
#
# **注意：** **缩进式插入前方必须有空行**
